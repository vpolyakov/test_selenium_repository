# %%
from selenium import webdriver
from browsermobproxy import Server
import json

# %%
server = Server("C:\\Chromedriver\\browsermob-proxy-2.1.4\\bin\\browsermob-proxy")
server.start()
proxy = server.create_proxy()

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--proxy-server={0}".format(proxy.proxy))
driver = webdriver.Chrome(chrome_options=chrome_options)

# %%
proxy.new_har("software-testing")
# driver.get("http://www.google.co.uk")
driver.get("http://software-testing.ru")

# %%
print(proxy.har)  # returns a HAR JSON blob
# Out:
# {'log': {'version': '1.2', 'creator': {'name': 'BrowserMob Proxy', 'version': '2.1.4', 'comment': ''}, 'pages': [{'id': 'software-testing', 'startedDateTime': '2018-10-21T04:24:31.606+04:00', 'title': 'software-testing', 'pageTimings': {'comment': ''}, 'comment': ''}], 'entries': [{'pageref': 'software-testing', 'startedDateTime': '2018-10-21T04:24:31.737+04:00', 'request': {'method': 'GET', 'url': 'http://software-testing.ru/', 'httpVersion': 'HTTP/1.1', 'cookies': [], 'headers': [], 'queryString': [], 'headersSize': 442, 'bodySize': 0, 'comment': ''}, 'response': {'status': 200, 'statusText': 'OK', 'httpVersion': 'HTTP/1.1', 'cookies': [], 'headers': [], 'content': {'size': 0, 'mimeType': 'text/html; charset=UTF-8', 'comment': ''}, 'redirectURL': '', 'headersSize': 617, 'bodySize': 24358, 'comment': ''}, 'cache': {}, 'timings': {'comment': '', 'dns': 93, 'wait': 121, 'ssl': -1, 'send': 0, 'receive': 124, 'connect': 73, 'blocked': 0}, 'serverIPAddress': '80.87.200.214', 'comment': '', 'time': 414}, {'pageref': 'software-testing', 'startedDateTime': '2018-10-21T04:24:32.110+04:00', 'request': {'method': 'GET', 'url': 'http://software-testing.ru/plugins/content/jw_disqus/tmpl/css/template.css', 'httpVersion': 'HTTP/1.1', 'cookies': [], 'headers': [], 'queryString': [], 'headersSize': 499, 'bodySize': 0, 'comment': ''}, 'response': {'status': 200, 'statusText': 'OK', 'httpVersion': 'HTTP/1.1', 'cookies': [], 'headers': [], 'content': {'size': 0, 'mimeType': 'text/css', 'comment': ''}, 'redirectURL': '', 'headersSize': 240, 'bodySize': 1605, 'comment': ''}, 'cache': {}, 'timings': {'comment': '', 'dns': 0, 'wait': 66, 'ssl': -1, 'send': 2, 'receive': 0, 'connect': 95, 'blocked': 0}, 'serverIPAddress': '80.87.200.214', 'comment': '', 'time': 165}, {'pageref': 'software-testing', 'startedDateTime': '2018-10-21T04:24:32.126+04:00', 'request': {'method': 'GET', 'url': 'http://s7.addthis.com/js/250/addthis_widget.js', 'httpVersion': 'HTTP/1.1', 'cookies': [], 'headers': [], 'queryString': [], 'headersSize': 382, 'bodySize': 0, 'comment': ''}, 'response': {'status': 200, 'statusText': 'OK', 'httpVersion': 'HTTP/1.1', 'cookies': [], 'headers': [], 'content': {'size': 0, 'mimeType': 'application/javascript', 'comment': ''}, 'redirectURL': '', 'headersSize': 439, 'bodySize': 114220, 'comment': ''}, 'cache': {}, 'timings': {'comment': '', 'dns': 346, 'wait': 139, 'ssl': -1, 'send': 1, 'receive': 639, 'connect': 186, 'blocked': 0}, 'serverIPAddress': '2.18.76.46', 'comment': '', 'time': 1312}, {'pageref': 'software-testing', 'startedDateTime': '2018-10-21T04:24:32.127+04:00', 'request': {'method': 'GET', 'url': 'http://software-testing.ru/media/system/js/caption.js', 'httpVersion': 'HTTP/1.1', 'cookies': [], 'headers': [], 'queryString': [], 'headersSize': 463, 'bodySize': 0, 'comment': ''}, 'response': {'status': 200, 'statusText': 'OK', 'httpVersion': 'HTTP/1.1', 'cookies': [], 'headers': [], 'content': {'size': 0, 'mimeType': 'application/javascript', 'comment': ''}, 'redirectURL': '', 'headersSize': 254, 'bodySize': 1963, 'comment': ''}, 'cache': {}, 'timings': {'comment': '', 'dns': 0, 'wait': 61, 'ssl': -1, 'send': 1, 'receive': 0, 'connect': 132, 'blocked': 0}, 'serverIPAddress': '80.87.200.214', 'comment': '', 'time': 196}, {'pageref': 'software-testing', 'startedDateTime': '2018-10-21T04:24:32.132+04:00', 'request': {'method': 'GET', 'url': 'http://software-testing.ru/templates/supra-mini/css/menu/dropdown.css', 'httpVersion': 'HTTP/1.1', 'cookies': [], 'headers': [], 'queryString': [], 'headersSize': 494, 'bodySize': 0, 'comment': ''}, 'response': {'status': 200, 'statusText': 'OK', 'httpVersion': 'HTTP/1.1', 'cookies': [], 'headers': [], 'content': {'size': 0, 'mimeType': 'text/css', 'comment': ''}, 'redirectURL': '', 'headersSize': 241, 'bodySize': 8499, 'comment': ''}, 'cache': {}, 'timings': {'comment': '', 'dns': 0, 'wait': 60, 'ssl': -1, 'send': 1, 'receive': 41, 'connect': 129, 'blocked': 0}, 'serverIPAddress': '80.87.200.2 ...

# %%
server.stop()

# %%
for key in proxy.har['log']['creator']:
    print(key, proxy.har['log']['creator'][key])
# Out:
# name BrowserMob Proxy
# version 2.1.4
# comment

# %%
driver.quit()
